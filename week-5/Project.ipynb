# %%
import tkinter as tk
from tkinter import messagebox
from PIL import Image, ImageTk

def welcomeMessageLogis(name):
    # Create a Tkinter window
    window = tk.Toplevel(root)
    window.title("Verification Form")
    window.geometry("500x200")

    label_1 = tk.Label(window, text="GIG LOGISTICS DEPARTMENT OF EMPLOYEES")
    label_1.pack()
    label_1 = tk.Label(window, text = "ADENIRAN Oluwatam\n AGBAKWU Chiemezie\n ARNIKA Osose\n CHUKWUMA Nedi\n EZEONYE Makuochukwu\n")
    label_1.pack()
    
def welcomeMessageAccount(name):
    # Create a Tkinter window
    window = tk.Toplevel(root)
    window.title("Verification Checker")
    window.geometry("500x300")

    label_1 = tk.Label(window, text="GIG ACCOUNTING DEPARTMENT EMPLOYEES:",)
    label_1.pack()
    label_1 = tk.Label(window, text = "ADEWUMI Ayomide\n AGBAKURU-NWOGU Chukwunonye\n AKINDE Oluwatimehin\n EBI Stephanie\n ICHA Ayonete\n")
    label_1.pack()

def welcomeMessageAdmini(name):
    # Create a Tkinter window 
    window = tk.Toplevel(root)
    window.title("Verification Checker")
    window.geometry("500x400")

    label_1 = tk.Label(window, text="GIG ADMINISTRATION DEPARTMENT EMPLOYEES:",)
    label_1.pack()
    label_1 = tk.Label(window, text = "EGBORO Jason\n ELERI Otu\n EZE Onyinyech\n OKOCHA- Rapheal\n OKOLO Victor\n UMEH Ejike")
    label_1.pack()
    
def welcomeMessageDeliver(name):
    # Create a Tkinter window
    window = tk.Toplevel(root)
    window.title("Verfication Checker")
    window.geometry("500x500")

    label_1 = tk.Label(window, text="GIG DELIVERY DEPARTMENT EMPLOYEES:")
    label_1.pack()
    label_1 = tk.Label(window, text = "ADOH-AJA Oshim\n ATELLY Daniel\n AZOGU Onyekachi\n BETURE Shalom\n EJEDIMU Edward\n ILOENYOS Michael\n IYAWE Oluwadam\n OGBAONNA Boluwatife\n OIGBOCHI Mary\n OSSAI Mary-Cynt\n UBE-IBE Uchenna")
    
def submit():
    name = name_entry.get()
    department = department_entry.get()

    if department == "Accounting":
      if name == "Adewunmi" or name == "Agbakuru-Nwogu" or name == "Akinde" or name == "Ebi" or name == "Icha" or name == "Ikpati" or name == "Obasogie":
          messagebox.showinfo("Success", f"Welcome Employee, {name}!")
          welcomeMessageAccount(name)
      else:
          messagebox.showerror("Login", "Cannot verify user")

    elif department == "Administration":
        if name == "Egboro" or name == "Eleri" or name == "Eze" or name == "Okocha-Ojeah" or name == "Okolo" or name == "Umeh":
            messagebox.showinfo("Success", f"Welcome Employee, {name}!")
            welcomeMessageAdmini(name)
        else:
            messagebox.showerror("Login", "Cannot verify user")

    elif department == "Delivery":
        if name == "Adoh-Ajagbo" or name == "Atelly" or name == "Azugo" or name == "Beture" or name == "Ejedimu" or name == "Iloenyosi" or name == "Iyawu":
            messagebox.showinfo("Success", f"Welcome Employee, {name}!")
            welcomeMessageDeliver(name)
        else:
            messagebox.showerror("Login", "Cannot verify user")
    elif department == "Logistics":
        if name == "Adeniran" or name == "Agbakwuru" or name == "Anika" or name == "Chukwuma" or name == "Ezeonye" or name == "Giwa" or name == "Nwokolo":
            messagebox.showinfo("Success", f"Welcome Employee, {name}!")
            welcomeMessageLogis(name)
        else:
            messagebox.showerror("Login", "Cannot verify user")

    else:
        messagebox.showerror("Login", "Cannot verify user")
# Create main window
root = tk.Tk()
root.title("Verification Checker")
root.geometry("800x300")

# Create username label and entry
name_label = tk.Label(root, text="First Name:")
name_label.pack()
name_entry = tk.Entry(root)
name_entry.pack()

# Create department label and entry
department_label = tk.Label(root, text="Department:")
department_label.pack()
department_entry = tk.Entry(root)
department_entry.pack()



# Create submit button
submit_button = tk.Button(root, text="Submit", command=submit)
submit_button.pack()

# Run the main event loop
root.mainloop()
