# %%
import tkinter as tk
from tkinter import messagebox
from PIL import Image, ImageTk

def pricebox1(weight,location):
    # Create tkinter window
    window = tk.Toplevel(root)
    window.title("Price Form")
    window.geometry("500x200")

    label_1 = tk.Label(window, text="Price for package ordered")
    label_1.pack()
    label_1 = tk.Label(window, text = "Price is 5,000 for package weight of 10 kg and above and delivery in Lekki community")
    label_1.pack()

def pricebox2(weight,location):
    # Create tkinter window
    window = tk.Toplevel(root)
    window.title("Price Form")
    window.geometry("500x200")

    label_1 = tk.Label(window, text="Price for package ordered")
    label_1.pack()
    label_1 = tk.Label(window, text = "Price is 3,500 for package weight of 10kg and below and delivery in Lekki community")
    label_1.pack()

def pricebox3(weight,location):
    # Create tkinter window
    window = tk.Toplevel(root)
    window.title("Price Form")
    window.geometry("500x300")

    label_1 = tk.Label(window, text="Price for package ordered")
    label_1.pack()
    label_1 = tk.Label(window, text = "Price is N10,000 for package weight of 10kg and above and delivery in Epe")
    label_1.pack()

def pricebox4(weight,location):
    # Create tkinter window
    window = tk.Toplevel(root)
    window.title("Price Form")
    window.geometry("500x200")

    label_1 = tk.Label(window, text="Price for package ordered")
    label_1.pack()
    label_1 = tk.Label(window, text = "Price is N5,000 for package weight of 10kg and below and delivery in Epe")
    label_1.pack()

def submit():
    location = location_entry.get()
    weight = float(weight_entry.get())

    if weight >= 10 and location == "ibeju-Lekki community":
        messagebox.showinfo("Welcome", f"Thank you for using Simi Services")
        pricebox1(weight,location)
    elif weight < 10 and location == "ibeju-Lekki community":
        messagebox.showinfo("Welcome", f"Thank you for using Simi Services")
        pricebox2(weight,location)
    elif weight >= 10 and location == "Epe":
        messagebox.showinfo("Welcome", f"Thank you for using Simi Services")
        pricebox3(weight,location)
    elif weight < 10 and location == "Epe":
        messagebox.showinfo("Welcome", f"Thank you for using Simi Services")
        pricebox4(weight,location)
    else:
        messagebox.showerror("Information not processed")
# Create main window
root = tk.Tk()
root.title("Price box")
root.geometry("800x300")

# Create location label and entry
location_label = tk.Label(root, text="Location:")
location_label.pack()
location_entry = tk.Entry(root)
location_entry.pack()

# Create weight label and entry
weight_label = tk.Label(root, text="Weight:")
weight_label.pack()
weight_entry = tk.Entry(root)
weight_entry.pack()

# Create submit button
submit_button = tk.Button(root, text="Submit", command=submit)
submit_button.pack()

# Run the main event loop
root.mainloop()

# %%
import tkinter as tk
from tkinter import messagebox
from PIL import Image, ImageTk
from array import *

def compsci():
    # Create tkinter window
    window = tk.Toplevel(root)
    window.title("Admission Verification")
    window.geometry("800x200")

    label_1 = tk.Label(window, text="")
    label_1.pack()
    label_1 = tk.Label(window, text= "admitted" )
    label_1.pack()


def masscom():
    # Create tkinter window
    window = tk.Toplevel(root)
    window.title("Admission Verification")
    window.geometry("800x200")

    label_1 = tk.Label(window, text="")
    label_1.pack()
    label_1 = tk.Label(window, text = "")
    label_1.pack()
    
def submit():
    Name = str(Name_entry.get())
    Course = str(Course_entry.get())
    Score = int(Score_entry.get())
    Mathematics = str(Mathematics_entry.get())
    English = str(English_entry.get())
    Physics = str(Physics_entry.get())
    Chemistry = str(Chemistry_entry.get())
    Literature = str(Literature_entry.get())
    Government = str(Government_entry.get())
    Biology = str(Biology_entry.get())
    Interview = str(Interview_entry.get())
    
    admitted = []
    notadmitted = []
   
    if Course == "Computer Science" and Score >= 250 and (Mathematics in {"A", "B", "C"}) and (English in {"A", "B", "C"}) and (Physics in {"A", "B", "C"}) and (Chemistry in {"A", "B", "C"}) and (Biology in {"A", "B", "C"}) and Interview == "Yes":
        messagebox.showinfo("Congratulations", f"You have been admitted")
        admitted.append(Name)
        admitted.append(Course)
        admitted.append(Score)
        admitted.append(Mathematics)
        admitted.append(English)
        admitted.append(Physics)
        admitted.append(Chemistry)
        admitted.append(Biology)
        admitted.append(Interview)
        print("Students Information ", admitted)

    elif Course == "Mass Communication" and Score >= 230 and (Mathematics in {"A", "B", "C"}) and (English in {"A", "B", "C"}) and (Literature in {"A", "B", "C"}) and (Government in {"A", "B", "C"}) and (Biology in {"A", "B", "C"}) and Interview == "Yes":
        messagebox.showinfo("Congratulations", f"You have been admitted")
        admitted.append(Name)
        admitted.append(Course)
        admitted.append(Score)
        admitted.append(Mathematics)
        admitted.append(English)
        admitted.append(Literature)
        admitted.append(Government)
        admitted.append(Biology)
        admitted.append(Interview)
        print("Students Information ", admitted)
    else:
        messagebox.showerror("Sorry", f"You have not been admitted")
        notadmitted.append(Name)
        notadmitted.append(Course)
        notadmitted.append(Score)
        notadmitted.append(Mathematics)
        notadmitted.append(English)
        notadmitted.append(Physics)
        notadmitted.append(Chemistry)
        notadmitted.append(Biology)
        notadmitted.append(Interview)
        print("Students Information ", notadmitted)
        
# Create main window
root = tk.Tk()
root.title("Admission Verification Checker")
root.geometry("600x550")

# Create username label and entry
Name_label = tk.Label(root, text="Enter Name:")
Name_label.pack()
Name_entry = tk.Entry(root)
Name_entry.pack()
    
Course_label = tk.Label(root, text="Enter Course:")
Course_label.pack()
Course_entry = tk.Entry(root)
Course_entry.pack()

# Create department label and entry
Score_label = tk.Label(root, text="Enter UTME Score:")
Score_label.pack()
Score_entry = tk.Entry(root)
Score_entry.pack()

Mathematics_label = tk.Label(root, text="Enter Mathematics Grade:")
Mathematics_label.pack()
Mathematics_entry = tk.Entry(root)
Mathematics_entry.pack()

English_label = tk.Label(root, text="Enter English Grade:")
English_label.pack()
English_entry = tk.Entry(root)
English_entry.pack()

Physics_label = tk.Label(root, text="Enter Physics Grade:")
Physics_label.pack()
Physics_entry = tk.Entry(root)
Physics_entry.pack()

Chemistry_label = tk.Label(root, text="Enter Chemistry Grade:")
Chemistry_label.pack()
Chemistry_entry = tk.Entry(root)
Chemistry_entry.pack()

Biology_label = tk.Label(root, text="Enter Biology Grade:")
Biology_label.pack()
Biology_entry = tk.Entry(root)
Biology_entry.pack()

Literature_label = tk.Label(root, text="Enter Literature Grade:")
Literature_label.pack()
Literature_entry = tk.Entry(root)
Literature_entry.pack()

Government_label = tk.Label(root, text="Enter Government Grade:")
Government_label.pack()
Government_entry = tk.Entry(root)
Government_entry.pack()

Interview_label = tk.Label(root, text="Did you pass the interview <YES/NO>:")
Interview_label.pack()
Interview_entry = tk.Entry(root)
Interview_entry.pack()

# Create submit button
submit_button = tk.Button(root, text="Submit", command=submit)
submit_button.pack()

# Run the main event loop
root.mainloop()
